# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
import time
from datetime import datetime
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 699

# %%
#create weatherapi url
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["main"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date, 
                          "Current Description": city_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | cidreira
# Processing Record 2 of Set 1 | sisimiut
# Processing Record 3 of Set 1 | soddy-daisy
# Processing Record 4 of Set 1 | bam
# Processing Record 5 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 6 of Set 1 | isangel
# Processing Record 7 of Set 1 | khatanga
# Processing Record 8 of Set 1 | nikolskoye
# Processing Record 9 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 10 of Set 1 | hithadhoo
# Processing Record 11 of Set 1 | bambous virieux
# Processing Record 12 of Set 1 | tucano
# Processing Record 13 of Set 1 | punta arenas
# Processing Record 14 of Set 1 | ondo
# Processing Record 15 of Set 1 | necochea
# Processing Record 16 of Set 1 | bredasdorp
# Processing Record 17 of Set 1 | esperance
# Processing Record 18 of Set 1 | araouane
# Processing Record 19 of Set 1 | pevek
# Processing Record 20 of Set 1 | albany
# Processing Record 21 of Set 1 | bluff
# Processing Record 22 of Set 1 | cabo san lucas
# Processing Record 23 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 24 of Set 1 | xushan
# Processing Record 25 of Set 1 | xuanhua
# Processing Record 26 of Set 1 | upernavik
# Processing Record 27 of Set 1 | airai
# Processing Record 28 of Set 1 | mataura
# Processing Record 29 of Set 1 | fevralsk
# City not found. Skipping...
# Processing Record 30 of Set 1 | severo-kurilsk
# Processing Record 31 of Set 1 | san patricio
# Processing Record 32 of Set 1 | port alfred
# Processing Record 33 of Set 1 | barrow
# Processing Record 34 of Set 1 | biak
# Processing Record 35 of Set 1 | sistranda
# Processing Record 36 of Set 1 | touros
# Processing Record 37 of Set 1 | matamoros
# Processing Record 38 of Set 1 | cape town
# Processing Record 39 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 1 | lata
# Processing Record 41 of Set 1 | coos bay
# Processing Record 42 of Set 1 | moreira sales
# Processing Record 43 of Set 1 | alice springs
# Processing Record 44 of Set 1 | laguna
# Processing Record 45 of Set 1 | tecoanapa
# Processing Record 46 of Set 1 | hobart
# Processing Record 47 of Set 1 | richards bay
# Processing Record 48 of Set 1 | lorengau
# Processing Record 49 of Set 1 | rikitea
# Processing Record 50 of Set 1 | pawai
# Processing Record 1 of Set 2 | sitka
# Processing Record 2 of Set 2 | jieshi
# Processing Record 3 of Set 2 | calabozo
# Processing Record 4 of Set 2 | bethel
# Processing Record 5 of Set 2 | luba
# Processing Record 6 of Set 2 | vao
# Processing Record 7 of Set 2 | vaini
# Processing Record 8 of Set 2 | ushuaia
# Processing Record 9 of Set 2 | riyadh
# Processing Record 10 of Set 2 | hvide sande
# Processing Record 11 of Set 2 | dunedin
# Processing Record 12 of Set 2 | bathsheba
# Processing Record 13 of Set 2 | egvekinot
# Processing Record 14 of Set 2 | kapaa
# Processing Record 15 of Set 2 | gunjur
# Processing Record 16 of Set 2 | nemuro
# Processing Record 17 of Set 2 | yumen
# Processing Record 18 of Set 2 | kaitangata
# Processing Record 19 of Set 2 | nelson bay
# Processing Record 20 of Set 2 | atuona
# Processing Record 21 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 22 of Set 2 | puerto ayora
# Processing Record 23 of Set 2 | puerto cabello
# Processing Record 24 of Set 2 | narsaq
# Processing Record 25 of Set 2 | fortuna
# Processing Record 26 of Set 2 | kaele
# Processing Record 27 of Set 2 | butaritari
# Processing Record 28 of Set 2 | tasiilaq
# Processing Record 29 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 30 of Set 2 | ponta do sol
# Processing Record 31 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 32 of Set 2 | east london
# Processing Record 33 of Set 2 | saint-georges
# Processing Record 34 of Set 2 | busselton
# Processing Record 35 of Set 2 | avarua
# Processing Record 36 of Set 2 | chiredzi
# Processing Record 37 of Set 2 | bengkulu
# Processing Record 38 of Set 2 | la primavera
# Processing Record 39 of Set 2 | caranavi
# Processing Record 40 of Set 2 | ribeira grande
# Processing Record 41 of Set 2 | hilo
# Processing Record 42 of Set 2 | dikson
# Processing Record 43 of Set 2 | mosquera
# Processing Record 44 of Set 2 | ahipara
# Processing Record 45 of Set 2 | new norfolk
# Processing Record 46 of Set 2 | gogrial
# Processing Record 47 of Set 2 | gat
# Processing Record 48 of Set 2 | komsomolskiy
# Processing Record 49 of Set 2 | kawalu
# Processing Record 50 of Set 2 | kathu
# Processing Record 1 of Set 3 | vila velha
# Processing Record 2 of Set 3 | torrington
# Processing Record 3 of Set 3 | poum
# Processing Record 4 of Set 3 | kahului
# Processing Record 5 of Set 3 | port hedland
# Processing Record 6 of Set 3 | hurricane
# Processing Record 7 of Set 3 | palauig
# Processing Record 8 of Set 3 | la ronge
# Processing Record 9 of Set 3 | wasilla
# Processing Record 10 of Set 3 | atchison
# Processing Record 11 of Set 3 | opuwo
# Processing Record 12 of Set 3 | itanhaem
# Processing Record 13 of Set 3 | panaba
# Processing Record 14 of Set 3 | sawakin
# Processing Record 15 of Set 3 | sidney
# Processing Record 16 of Set 3 | naze
# Processing Record 17 of Set 3 | rawannawi
# City not found. Skipping...
# Processing Record 18 of Set 3 | yevpatoriya
# Processing Record 19 of Set 3 | vestmannaeyjar
# Processing Record 20 of Set 3 | aklavik
# Processing Record 21 of Set 3 | bartica
# Processing Record 22 of Set 3 | yellowknife
# Processing Record 23 of Set 3 | grand-santi
# Processing Record 24 of Set 3 | port elizabeth
# Processing Record 25 of Set 3 | praia
# Processing Record 26 of Set 3 | castro
# Processing Record 27 of Set 3 | privolzhskiy
# Processing Record 28 of Set 3 | mar del plata
# Processing Record 29 of Set 3 | caravelas
# Processing Record 30 of Set 3 | camacha
# Processing Record 31 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 32 of Set 3 | hovd
# Processing Record 33 of Set 3 | qaanaaq
# Processing Record 34 of Set 3 | kodiak
# Processing Record 35 of Set 3 | rio gallegos
# Processing Record 36 of Set 3 | alyangula
# Processing Record 37 of Set 3 | maarianhamina
# Processing Record 38 of Set 3 | kattivakkam
# Processing Record 39 of Set 3 | vendas novas
# Processing Record 40 of Set 3 | nuuk
# Processing Record 41 of Set 3 | rusape
# Processing Record 42 of Set 3 | ancud
# Processing Record 43 of Set 3 | nara
# Processing Record 44 of Set 3 | jamestown
# Processing Record 45 of Set 3 | tazovskiy
# Processing Record 46 of Set 3 | ponta delgada
# Processing Record 47 of Set 3 | mount isa
# Processing Record 48 of Set 3 | torbay
# Processing Record 49 of Set 3 | longyearbyen
# Processing Record 50 of Set 3 | gemena
# Processing Record 1 of Set 4 | dingle
# Processing Record 2 of Set 4 | havelock
# Processing Record 3 of Set 4 | hermanus
# Processing Record 4 of Set 4 | souillac
# Processing Record 5 of Set 4 | mareeba
# Processing Record 6 of Set 4 | tekeli
# Processing Record 7 of Set 4 | arinos
# Processing Record 8 of Set 4 | vuktyl
# Processing Record 9 of Set 4 | padang
# Processing Record 10 of Set 4 | lompoc
# Processing Record 11 of Set 4 | kavieng
# Processing Record 12 of Set 4 | tezu
# Processing Record 13 of Set 4 | antibes
# Processing Record 14 of Set 4 | emerald
# Processing Record 15 of Set 4 | nalut
# Processing Record 16 of Set 4 | vilyuysk
# Processing Record 17 of Set 4 | tuktoyaktuk
# Processing Record 18 of Set 4 | te anau
# Processing Record 19 of Set 4 | sorland
# Processing Record 20 of Set 4 | saint-philippe
# Processing Record 21 of Set 4 | vostok
# Processing Record 22 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 23 of Set 4 | constitucion
# Processing Record 24 of Set 4 | adrar
# Processing Record 25 of Set 4 | pizarro
# Processing Record 26 of Set 4 | ilulissat
# Processing Record 27 of Set 4 | barra patuca
# Processing Record 28 of Set 4 | vanimo
# Processing Record 29 of Set 4 | kaohsiung
# Processing Record 30 of Set 4 | kazalinsk
# City not found. Skipping...
# Processing Record 31 of Set 4 | nikel
# Processing Record 32 of Set 4 | macusani
# Processing Record 33 of Set 4 | provideniya
# Processing Record 34 of Set 4 | port blair
# Processing Record 35 of Set 4 | goderich
# Processing Record 36 of Set 4 | kommunisticheskiy
# Processing Record 37 of Set 4 | itarema
# Processing Record 38 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 39 of Set 4 | zeya
# Processing Record 40 of Set 4 | college
# Processing Record 41 of Set 4 | saiha
# Processing Record 42 of Set 4 | esqueda
# Processing Record 43 of Set 4 | charleston
# Processing Record 44 of Set 4 | georgetown
# Processing Record 45 of Set 4 | uyskoye
# Processing Record 46 of Set 4 | krasnoselkup
# Processing Record 47 of Set 4 | ilhabela
# Processing Record 48 of Set 4 | meulaboh
# Processing Record 49 of Set 4 | norman wells
# Processing Record 50 of Set 4 | asau
# Processing Record 1 of Set 5 | cayenne
# Processing Record 2 of Set 5 | pangoa
# Processing Record 3 of Set 5 | filingue
# Processing Record 4 of Set 5 | pisco
# Processing Record 5 of Set 5 | callaway
# Processing Record 6 of Set 5 | antofagasta
# Processing Record 7 of Set 5 | namibe
# Processing Record 8 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 9 of Set 5 | mancio lima
# Processing Record 10 of Set 5 | tiksi
# Processing Record 11 of Set 5 | hasaki
# Processing Record 12 of Set 5 | lavrentiya
# Processing Record 13 of Set 5 | boa vista
# Processing Record 14 of Set 5 | stephenville crossing
# Processing Record 15 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 16 of Set 5 | kemise
# Processing Record 17 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 18 of Set 5 | yinchuan
# Processing Record 19 of Set 5 | zalantun
# Processing Record 20 of Set 5 | saskylakh
# Processing Record 21 of Set 5 | arkhipo-osipovka
# Processing Record 22 of Set 5 | faya
# Processing Record 23 of Set 5 | akdepe
# Processing Record 24 of Set 5 | beloha
# Processing Record 25 of Set 5 | san jose
# Processing Record 26 of Set 5 | palmer
# Processing Record 27 of Set 5 | viedma
# Processing Record 28 of Set 5 | cherdyn
# Processing Record 29 of Set 5 | kamiiso
# Processing Record 30 of Set 5 | gurupi
# Processing Record 31 of Set 5 | neuquen
# Processing Record 32 of Set 5 | geraldton
# Processing Record 33 of Set 5 | riberalta
# Processing Record 34 of Set 5 | xining
# Processing Record 35 of Set 5 | nantucket
# Processing Record 36 of Set 5 | road town
# Processing Record 37 of Set 5 | hwange
# Processing Record 38 of Set 5 | katsuura
# Processing Record 39 of Set 5 | salalah
# Processing Record 40 of Set 5 | acapulco
# Processing Record 41 of Set 5 | eucaliptus
# Processing Record 42 of Set 5 | nizhniy tsasuchey
# Processing Record 43 of Set 5 | carnarvon
# Processing Record 44 of Set 5 | talnakh
# Processing Record 45 of Set 5 | valle de allende
# Processing Record 46 of Set 5 | kytmanovo
# Processing Record 47 of Set 5 | tabou
# Processing Record 48 of Set 5 | dubbo
# Processing Record 49 of Set 5 | kagoro
# Processing Record 50 of Set 5 | staryy nadym
# Processing Record 1 of Set 6 | beruni
# City not found. Skipping...
# Processing Record 2 of Set 6 | veraval
# Processing Record 3 of Set 6 | arraial do cabo
# Processing Record 4 of Set 6 | ulladulla
# Processing Record 5 of Set 6 | saint george
# Processing Record 6 of Set 6 | malkerns
# Processing Record 7 of Set 6 | baykit
# Processing Record 8 of Set 6 | guane
# Processing Record 9 of Set 6 | calama
# Processing Record 10 of Set 6 | harper
# Processing Record 11 of Set 6 | tobias barreto
# Processing Record 12 of Set 6 | pangnirtung
# Processing Record 13 of Set 6 | seguela
# Processing Record 14 of Set 6 | makakilo city
# Processing Record 15 of Set 6 | westport
# Processing Record 16 of Set 6 | huarmey
# Processing Record 17 of Set 6 | bontang
# Processing Record 18 of Set 6 | mangrol
# Processing Record 19 of Set 6 | najran
# Processing Record 20 of Set 6 | nainpur
# Processing Record 21 of Set 6 | jingdezhen
# Processing Record 22 of Set 6 | pervomayskoye
# Processing Record 23 of Set 6 | san cristobal
# Processing Record 24 of Set 6 | alta floresta
# Processing Record 25 of Set 6 | kaeo
# Processing Record 26 of Set 6 | lebu
# Processing Record 27 of Set 6 | kruisfontein
# Processing Record 28 of Set 6 | findhorn
# Processing Record 29 of Set 6 | sulangan
# Processing Record 30 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 31 of Set 6 | mezen
# Processing Record 32 of Set 6 | chopinzinho
# Processing Record 33 of Set 6 | puerto carreno
# Processing Record 34 of Set 6 | tinsukia
# Processing Record 35 of Set 6 | marzuq
# Processing Record 36 of Set 6 | keti bandar
# Processing Record 37 of Set 6 | beringovskiy
# Processing Record 38 of Set 6 | hervey bay
# Processing Record 39 of Set 6 | deputatskiy
# Processing Record 40 of Set 6 | obo
# Processing Record 41 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 42 of Set 6 | pangai
# Processing Record 43 of Set 6 | takoradi
# Processing Record 44 of Set 6 | mackay
# Processing Record 45 of Set 6 | warrington
# Processing Record 46 of Set 6 | gambo
# Processing Record 47 of Set 6 | chuy
# Processing Record 48 of Set 6 | sarai sidhu
# Processing Record 49 of Set 6 | waingapu
# Processing Record 50 of Set 6 | uthal
# Processing Record 1 of Set 7 | chokurdakh
# Processing Record 2 of Set 7 | vitim
# Processing Record 3 of Set 7 | sokol
# Processing Record 4 of Set 7 | livingston
# Processing Record 5 of Set 7 | olinda
# Processing Record 6 of Set 7 | fenoarivo
# Processing Record 7 of Set 7 | sindou
# Processing Record 8 of Set 7 | adelaide
# Processing Record 9 of Set 7 | dolgorukovo
# Processing Record 10 of Set 7 | victoria
# Processing Record 11 of Set 7 | upata
# Processing Record 12 of Set 7 | korla
# Processing Record 13 of Set 7 | shingu
# Processing Record 14 of Set 7 | larsnes
# Processing Record 15 of Set 7 | verkhnevilyuysk
# Processing Record 16 of Set 7 | brookhaven
# Processing Record 17 of Set 7 | peace river
# Processing Record 18 of Set 7 | ulaanbaatar
# Processing Record 19 of Set 7 | sao filipe
# Processing Record 20 of Set 7 | chernyshevskiy
# Processing Record 21 of Set 7 | iqaluit
# Processing Record 22 of Set 7 | usinsk
# Processing Record 23 of Set 7 | heishan
# Processing Record 24 of Set 7 | berezovyy
# Processing Record 25 of Set 7 | peshkopi
# Processing Record 26 of Set 7 | jardim
# Processing Record 27 of Set 7 | kindu
# Processing Record 28 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 29 of Set 7 | nouakchott
# Processing Record 30 of Set 7 | wajima
# Processing Record 31 of Set 7 | umm lajj
# Processing Record 32 of Set 7 | hanstholm
# Processing Record 33 of Set 7 | kavaratti
# Processing Record 34 of Set 7 | tautira
# Processing Record 35 of Set 7 | marsabit
# Processing Record 36 of Set 7 | sao joao da barra
# Processing Record 37 of Set 7 | tura
# Processing Record 38 of Set 7 | buqayq
# City not found. Skipping...
# Processing Record 39 of Set 7 | puerto colombia
# Processing Record 40 of Set 7 | frydlant nad ostravici
# Processing Record 41 of Set 7 | trincomalee
# Processing Record 42 of Set 7 | slatina
# Processing Record 43 of Set 7 | tacuarembo
# Processing Record 44 of Set 7 | margate
# Processing Record 45 of Set 7 | puerto penasco
# Processing Record 46 of Set 7 | brigantine
# Processing Record 47 of Set 7 | kerrville
# Processing Record 48 of Set 7 | fort madison
# Processing Record 49 of Set 7 | bac giang
# Processing Record 50 of Set 7 | qinzhou
# Processing Record 1 of Set 8 | presidencia roque saenz pena
# Processing Record 2 of Set 8 | straumen
# Processing Record 3 of Set 8 | ballina
# Processing Record 4 of Set 8 | kulhudhuffushi
# Processing Record 5 of Set 8 | mahebourg
# Processing Record 6 of Set 8 | mezhdurechensk
# Processing Record 7 of Set 8 | christchurch
# Processing Record 8 of Set 8 | russkiy aktash
# Processing Record 9 of Set 8 | maniitsoq
# Processing Record 10 of Set 8 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 11 of Set 8 | maceio
# Processing Record 12 of Set 8 | tawang
# Processing Record 13 of Set 8 | sao miguel do araguaia
# Processing Record 14 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 15 of Set 8 | thompson
# Processing Record 16 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 17 of Set 8 | campbellton
# Processing Record 18 of Set 8 | karmana
# City not found. Skipping...
# Processing Record 19 of Set 8 | los llanos de aridane
# Processing Record 20 of Set 8 | luderitz
# Processing Record 21 of Set 8 | tuatapere
# Processing Record 22 of Set 8 | teknaf
# Processing Record 23 of Set 8 | yar-sale
# Processing Record 24 of Set 8 | omboue
# Processing Record 25 of Set 8 | marathon
# Processing Record 26 of Set 8 | sosnovo-ozerskoye
# Processing Record 27 of Set 8 | juneau
# Processing Record 28 of Set 8 | pauini
# Processing Record 29 of Set 8 | turukhansk
# Processing Record 30 of Set 8 | prince rupert
# Processing Record 31 of Set 8 | starkville
# Processing Record 32 of Set 8 | agadez
# Processing Record 33 of Set 8 | bubaque
# Processing Record 34 of Set 8 | tessalit
# Processing Record 35 of Set 8 | motygino
# Processing Record 36 of Set 8 | paita
# Processing Record 37 of Set 8 | abha
# Processing Record 38 of Set 8 | faanui
# Processing Record 39 of Set 8 | grindavik
# Processing Record 40 of Set 8 | carahue
# Processing Record 41 of Set 8 | cherskiy
# Processing Record 42 of Set 8 | sinnar
# Processing Record 43 of Set 8 | hamilton
# Processing Record 44 of Set 8 | bohodukhiv
# Processing Record 45 of Set 8 | solovetskiy
# City not found. Skipping...
# Processing Record 46 of Set 8 | pingliang
# Processing Record 47 of Set 8 | grand gaube
# Processing Record 48 of Set 8 | bairnsdale
# Processing Record 49 of Set 8 | puro
# Processing Record 50 of Set 8 | monrovia
# Processing Record 1 of Set 9 | coahuayana
# Processing Record 2 of Set 9 | ondorhaan
# City not found. Skipping...
# Processing Record 3 of Set 9 | port-gentil
# Processing Record 4 of Set 9 | murgab
# Processing Record 5 of Set 9 | mpika
# Processing Record 6 of Set 9 | prabumulih
# Processing Record 7 of Set 9 | portland
# Processing Record 8 of Set 9 | paulo afonso
# Processing Record 9 of Set 9 | sechura
# Processing Record 10 of Set 9 | aguimes
# Processing Record 11 of Set 9 | adra
# Processing Record 12 of Set 9 | santa vitoria do palmar
# Processing Record 13 of Set 9 | moyamba
# Processing Record 14 of Set 9 | zhigansk
# Processing Record 15 of Set 9 | praia da vitoria
# Processing Record 16 of Set 9 | waipawa
# Processing Record 17 of Set 9 | ziarat
# Processing Record 18 of Set 9 | monte patria
# Processing Record 19 of Set 9 | acajutla
# Processing Record 20 of Set 9 | sisophon
# Processing Record 21 of Set 9 | thinadhoo
# Processing Record 22 of Set 9 | devyatka
# City not found. Skipping...
# Processing Record 23 of Set 9 | comodoro rivadavia
# Processing Record 24 of Set 9 | kinablangan
# Processing Record 25 of Set 9 | alugan
# Processing Record 26 of Set 9 | basse
# Processing Record 27 of Set 9 | innisfail
# Processing Record 28 of Set 9 | aguada de pasajeros
# Processing Record 29 of Set 9 | mount gambier
# Processing Record 30 of Set 9 | santa comba
# Processing Record 31 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 32 of Set 9 | crotone
# Processing Record 33 of Set 9 | alotau
# City not found. Skipping...
# Processing Record 34 of Set 9 | leh
# Processing Record 35 of Set 9 | san andres
# Processing Record 36 of Set 9 | klaksvik
# Processing Record 37 of Set 9 | chapais
# Processing Record 38 of Set 9 | lyubim
# Processing Record 39 of Set 9 | guatire
# Processing Record 40 of Set 9 | guerrero negro
# Processing Record 41 of Set 9 | knysna
# Processing Record 42 of Set 9 | mopipi
# Processing Record 43 of Set 9 | kaseda
# Processing Record 44 of Set 9 | san quintin
# Processing Record 45 of Set 9 | honningsvag
# Processing Record 46 of Set 9 | saint anthony
# Processing Record 47 of Set 9 | nushki
# Processing Record 48 of Set 9 | grandview
# Processing Record 49 of Set 9 | mishan
# Processing Record 50 of Set 9 | saldanha
# Processing Record 1 of Set 10 | vila
# Processing Record 2 of Set 10 | bafra
# Processing Record 3 of Set 10 | malayal
# Processing Record 4 of Set 10 | biloela
# Processing Record 5 of Set 10 | uspenskaya
# Processing Record 6 of Set 10 | rawlins
# Processing Record 7 of Set 10 | husavik
# Processing Record 8 of Set 10 | abu kamal
# Processing Record 9 of Set 10 | pontianak
# Processing Record 10 of Set 10 | altoona
# Processing Record 11 of Set 10 | chicama
# Processing Record 12 of Set 10 | itacoatiara
# Processing Record 13 of Set 10 | nhulunbuy
# Processing Record 14 of Set 10 | qaqortoq
# Processing Record 15 of Set 10 | maghama
# City not found. Skipping...
# Processing Record 16 of Set 10 | bonthe
# Processing Record 17 of Set 10 | kenora
# Processing Record 18 of Set 10 | marsa matruh
# Processing Record 19 of Set 10 | ambo
# Processing Record 20 of Set 10 | miranda
# Processing Record 21 of Set 10 | chateau-thierry
# Processing Record 22 of Set 10 | sola
# Processing Record 23 of Set 10 | kusa
# Processing Record 24 of Set 10 | dunbar
# Processing Record 25 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 26 of Set 10 | forestville
# Processing Record 27 of Set 10 | rocha
# Processing Record 28 of Set 10 | columbus
# Processing Record 29 of Set 10 | turbat
# Processing Record 30 of Set 10 | the valley
# Processing Record 31 of Set 10 | cocorit
# Processing Record 32 of Set 10 | puerto baquerizo moreno
# Processing Record 33 of Set 10 | broome
# Processing Record 34 of Set 10 | sinnamary
# Processing Record 35 of Set 10 | lensk
# Processing Record 36 of Set 10 | clinton
# Processing Record 37 of Set 10 | kasangulu
# Processing Record 38 of Set 10 | ust-maya
# Processing Record 39 of Set 10 | karatau
# Processing Record 40 of Set 10 | christiansburg
# Processing Record 41 of Set 10 | amderma
# City not found. Skipping...
# Processing Record 42 of Set 10 | adre
# Processing Record 43 of Set 10 | kropotkin
# Processing Record 44 of Set 10 | panino
# Processing Record 45 of Set 10 | sedkyrkeshch
# Processing Record 46 of Set 10 | vallenar
# Processing Record 47 of Set 10 | ust-nera
# Processing Record 48 of Set 10 | las cruces
# Processing Record 49 of Set 10 | kambove
# Processing Record 50 of Set 10 | roald
# Processing Record 1 of Set 11 | amapa
# Processing Record 2 of Set 11 | berlevag
# Processing Record 3 of Set 11 | buraydah
# Processing Record 4 of Set 11 | inhambane
# Processing Record 5 of Set 11 | bulgan
# Processing Record 6 of Set 11 | high level
# Processing Record 7 of Set 11 | ust-ishim
# Processing Record 8 of Set 11 | ambilobe
# Processing Record 9 of Set 11 | sibu
# Processing Record 10 of Set 11 | jujuy
# City not found. Skipping...
# Processing Record 11 of Set 11 | arecibo
# Processing Record 12 of Set 11 | mehamn
# Processing Record 13 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 14 of Set 11 | uvat
# Processing Record 15 of Set 11 | port macquarie
# Processing Record 16 of Set 11 | burns lake
# Processing Record 17 of Set 11 | kudahuvadhoo
# Processing Record 18 of Set 11 | batsfjord
# Processing Record 19 of Set 11 | natal
# Processing Record 20 of Set 11 | haines junction
# Processing Record 21 of Set 11 | porto novo
# Processing Record 22 of Set 11 | cacapava do sul
# Processing Record 23 of Set 11 | andenes
# Processing Record 24 of Set 11 | chikoy
# City not found. Skipping...
# Processing Record 25 of Set 11 | auki
# Processing Record 26 of Set 11 | belaya gora
# Processing Record 27 of Set 11 | abu dhabi
# Processing Record 28 of Set 11 | alofi
# Processing Record 29 of Set 11 | port lincoln
# Processing Record 30 of Set 11 | arlit
# Processing Record 31 of Set 11 | panama city
# Processing Record 32 of Set 11 | athabasca
# Processing Record 33 of Set 11 | bolshevik
# Processing Record 34 of Set 11 | paamiut
# Processing Record 35 of Set 11 | misratah
# Processing Record 36 of Set 11 | miranorte
# City not found. Skipping...
# Processing Record 37 of Set 11 | lapithos
# Processing Record 38 of Set 11 | mayo
# Processing Record 39 of Set 11 | camana
# Processing Record 40 of Set 11 | port keats
# Processing Record 41 of Set 11 | lubango
# Processing Record 42 of Set 11 | luganville
# Processing Record 43 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 44 of Set 11 | caluquembe
# Processing Record 45 of Set 11 | burnie
# Processing Record 46 of Set 11 | tawkar
# City not found. Skipping...
# Processing Record 47 of Set 11 | westerland
# Processing Record 48 of Set 11 | kirakira
# Processing Record 49 of Set 11 | barrhead
# Processing Record 50 of Set 11 | baruun-urt
# Processing Record 1 of Set 12 | kolno
# Processing Record 2 of Set 12 | bulnes
# Processing Record 3 of Set 12 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 4 of Set 12 | santa cruz
# Processing Record 5 of Set 12 | baracoa
# Processing Record 6 of Set 12 | mae ramat
# Processing Record 7 of Set 12 | mogadishu
# Processing Record 8 of Set 12 | clyde river
# Processing Record 9 of Set 12 | vila franca do campo
# Processing Record 10 of Set 12 | muros
# Processing Record 11 of Set 12 | buluang
# Processing Record 12 of Set 12 | kailua
# Processing Record 13 of Set 12 | karratha
# Processing Record 14 of Set 12 | havre-saint-pierre
# Processing Record 15 of Set 12 | beaverlodge
# Processing Record 16 of Set 12 | ostrovnoy
# Processing Record 17 of Set 12 | boke
# Processing Record 18 of Set 12 | villa rica
# Processing Record 19 of Set 12 | thunder bay
# Processing Record 20 of Set 12 | shubarshi
# Processing Record 21 of Set 12 | carballo
# Processing Record 22 of Set 12 | rosarito
# Processing Record 23 of Set 12 | fairbanks
# Processing Record 24 of Set 12 | warnes
# Processing Record 25 of Set 12 | izvestkovyy
# Processing Record 26 of Set 12 | dhidhdhoo
# Processing Record 27 of Set 12 | massaguet
# Processing Record 28 of Set 12 | marovoay
# Processing Record 29 of Set 12 | pochutla
# Processing Record 30 of Set 12 | toyooka
# Processing Record 31 of Set 12 | correia pinto
# Processing Record 32 of Set 12 | vitimskiy
# City not found. Skipping...
# Processing Record 33 of Set 12 | bongandanga
# Processing Record 34 of Set 12 | rab
# City not found. Skipping...
# Processing Record 35 of Set 12 | srednekolymsk
# Processing Record 36 of Set 12 | honiara
# Processing Record 37 of Set 12 | san policarpo
# Processing Record 38 of Set 12 | qandala
# Processing Record 39 of Set 12 | waddan
# Processing Record 40 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 41 of Set 12 | grand centre
# City not found. Skipping...
# Processing Record 42 of Set 12 | bella union
# Processing Record 43 of Set 12 | hoi an
# Processing Record 44 of Set 12 | pafos
# Processing Record 45 of Set 12 | coihaique
# Processing Record 46 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 47 of Set 12 | san-pedro
# Processing Record 48 of Set 12 | saint-pierre
# Processing Record 49 of Set 12 | miri
# Processing Record 50 of Set 12 | ciudad bolivar
# Processing Record 1 of Set 13 | lagoa
# Processing Record 2 of Set 13 | laguna de perlas
# Processing Record 3 of Set 13 | rawson
# Processing Record 4 of Set 13 | mizoch
# Processing Record 5 of Set 13 | mitsamiouli
# Processing Record 6 of Set 13 | dukat
# Processing Record 7 of Set 13 | tyrma
# Processing Record 8 of Set 13 | sao jose da coroa grande
# Processing Record 9 of Set 13 | stochov
# Processing Record 10 of Set 13 | springbok
# Processing Record 11 of Set 13 | arsenyev
# Processing Record 12 of Set 13 | xiuyan
# Processing Record 13 of Set 13 | nadym
# Processing Record 14 of Set 13 | manta
# Processing Record 15 of Set 13 | cheuskiny
# City not found. Skipping...
# Processing Record 16 of Set 13 | vigrestad
# Processing Record 17 of Set 13 | fort nelson
# Processing Record 18 of Set 13 | hobyo
# Processing Record 19 of Set 13 | baie-comeau
# Processing Record 20 of Set 13 | udachnyy
# Processing Record 21 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 22 of Set 13 | marakkanam
# Processing Record 23 of Set 13 | cururupu
# Processing Record 24 of Set 13 | namatanai
# Processing Record 25 of Set 13 | bilma
# Processing Record 26 of Set 13 | tevaitoa
# Processing Record 27 of Set 13 | sanming
# Processing Record 28 of Set 13 | kutulik
# Processing Record 29 of Set 13 | santa helena de goias
# Processing Record 30 of Set 13 | okha
# Processing Record 31 of Set 13 | duz
# City not found. Skipping...
# Processing Record 32 of Set 13 | sobolevo
# Processing Record 33 of Set 13 | labutta
# City not found. Skipping...
# Processing Record 34 of Set 13 | kyren
# Processing Record 35 of Set 13 | ahuimanu
# Processing Record 36 of Set 13 | kieta
# Processing Record 37 of Set 13 | calvinia
# Processing Record 38 of Set 13 | konstantinovskiy
# Processing Record 39 of Set 13 | vardo
# Processing Record 40 of Set 13 | ridgetown
# Processing Record 41 of Set 13 | eyl
# Processing Record 42 of Set 13 | tongliao
# Processing Record 43 of Set 13 | fujin
# Processing Record 44 of Set 13 | warrnambool
# Processing Record 45 of Set 13 | kokstad
# Processing Record 46 of Set 13 | falavarjan
# Processing Record 47 of Set 13 | sao benedito do rio preto
# Processing Record 48 of Set 13 | taonan
# Processing Record 49 of Set 13 | saint-louis
# Processing Record 50 of Set 13 | guadalajara
# Processing Record 1 of Set 14 | kazachka
# Processing Record 2 of Set 14 | waianae
# Processing Record 3 of Set 14 | herzogenburg
# Processing Record 4 of Set 14 | port hardy
# Processing Record 5 of Set 14 | manokwari
# Processing Record 6 of Set 14 | yomitan
# City not found. Skipping...
# Processing Record 7 of Set 14 | basqal
# Processing Record 8 of Set 14 | imbituba
# Processing Record 9 of Set 14 | sembe
# Processing Record 10 of Set 14 | inta
# Processing Record 11 of Set 14 | kanniyakumari
# Processing Record 12 of Set 14 | mamit
# Processing Record 13 of Set 14 | ati
# Processing Record 14 of Set 14 | rehoboth
# Processing Record 15 of Set 14 | sorvag
# City not found. Skipping...
# Processing Record 16 of Set 14 | pitimbu
# Processing Record 17 of Set 14 | karakendzha
# City not found. Skipping...
# Processing Record 18 of Set 14 | tokur
# Processing Record 19 of Set 14 | burica
# City not found. Skipping...
# Processing Record 20 of Set 14 | muscat
# Processing Record 21 of Set 14 | bilibino
# Processing Record 22 of Set 14 | bagacay
# Processing Record 23 of Set 14 | nanortalik
# Processing Record 24 of Set 14 | lagos
# Processing Record 25 of Set 14 | yueyang
# Processing Record 26 of Set 14 | verkh-usugli
# Processing Record 27 of Set 14 | humberto de campos
# Processing Record 28 of Set 14 | floro
# Processing Record 29 of Set 14 | hambantota
# Processing Record 30 of Set 14 | nome
# Processing Record 31 of Set 14 | wuwei
# Processing Record 32 of Set 14 | ivisan
# Processing Record 33 of Set 14 | yarega
# Processing Record 34 of Set 14 | sioux lookout
# Processing Record 35 of Set 14 | jijiang
# Processing Record 36 of Set 14 | taltal
# Processing Record 37 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 38 of Set 14 | lethem
# Processing Record 39 of Set 14 | keflavik
# Processing Record 40 of Set 14 | olafsvik
# Processing Record 41 of Set 14 | iralaya
# Processing Record 42 of Set 14 | yulara
# Processing Record 43 of Set 14 | wageningen
# Processing Record 44 of Set 14 | rio grande
# Processing Record 45 of Set 14 | tuy hoa
# Processing Record 46 of Set 14 | gberia fotombu
# Processing Record 47 of Set 14 | nouadhibou
# Processing Record 48 of Set 14 | marawi
# Processing Record 49 of Set 14 | jinhua
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert into a DataFrame

city_data_df = pd.DataFrame(city_data)

city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Cidreira -30.1811  -50.2056     66.85        74           9
# 1         Sisimiut  66.9395  -53.6735      3.72        94         100
# 2      Soddy-Daisy  35.2359  -85.1908     33.53        87           0
# 3              Bam  29.1060   58.3570     52.72        29           6
# 4          Isangel -19.5500  169.2667     78.91        94         100
# 5         Khatanga  71.9667  102.5000    -18.33        98         100
# 6       Nikolskoye  59.7035   30.7861     35.87        97         100
# 7        Hithadhoo  -0.6000   73.0833     82.62        67          23
# 8  Bambous Virieux -20.3428   57.7575     81.21        78         100
# 9           Tucano -10.9631  -38.7867     71.96        93          78
#
#    Wind Speed Country                 Date Current Description
# 0        8.61      BR  2022-02-07 04:49:48               Clear
# 1       20.04      GL  2022-02-07 04:46:14                Snow
# 2        3.20      US  2022-02-07 04:49:49               Clear
# 3        2.84      IR  2022-02-07 04:46:31               Clear
# 4       13.80      VU  2022-02-07 04:49:50              Clouds
# 5        9.69      RU  2022-02-07 04:49:51              Clouds
# 6        7.16      RU  2022-02-07 04:49:51                Snow
# 7       14.25      MV  2022-02-07 04:49:52              Clouds
# 8       10.87      MU  2022-02-07 04:49:53              Clouds
# 9        4.47      BR  2022-02-07 04:49:54              Clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
